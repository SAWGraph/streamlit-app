# %% [markdown]
# This notebook generates a map to answer answer the following question:
# * Find industrial facilities that are upstream from surface water bodies with concerning PFAS sample results (e.g., > 4 ppt).

# %% [markdown]
# # Setup

# %%
# %%capture
# !pip install mapclassify
# !pip install SPARQLWrapper
# !pip install rdflib

# %%
# from branca.element import Figure                                  # For controlling the size of the final map
import folium                                                      # For map layer control
import geopandas as gpd                                            # For geospatial dataframes
import pandas as pd                                                # For dataframes
from shapely import wkt                                            # For working with WKT coordinates in a GeoDataFrame
from SPARQLWrapper import SPARQLWrapper2, JSON, GET, POST, DIGEST  # For querying SPARQL endpoints
import rdflib                                                      # For working with URIs

def convertToDataframe(results):
    d = []
    for x in results.bindings:
        row = {}
        for k in x:
            v = x[k]
            vv = rdflib.term.Literal(v.value, datatype=v.datatype).toPython()  # type: ignore[no-untyped-call]
            row[k] = vv
        d.append(row)
    df = pd.DataFrame(d)
    return df

def convertS2ListToQueryString(s2list):
    s2list = list(set(s2list))
    s2list_short = [s2cell.replace("http://stko-kwg.geog.ucsb.edu/lod/resource/","kwgr:") for s2cell in s2list]
    s2_values_string = " ".join(s2list_short)
    return s2_values_string

# %%
# for interactive widgets
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display

# %%
frink_fed_endpoint = 'https://frink.apps.renci.org/federation/sparql'

sparqlGET = SPARQLWrapper2(frink_fed_endpoint)
sparqlGET.setHTTPAuth(DIGEST)
sparqlGET.setMethod(POST)
sparqlGET.setReturnFormat(JSON)

# %% [markdown]
# # Find industrial facilities that are upstream from surface water bodies with concerning PFAS sample results (e.g., > 4 ppt).

# %%
#Parameters to choose

# TODO: indicate DSSToxID for each PFAS, query by DSSToxId
substance = "PFOA (DTXSID8031865)" # @param ["PFOS (DTXSID3031864)", "PFOA (DTXSID8031865)", "PFBA (DTXSID4059916)", "PFBS (DTXSID5030030)", "PFHPA (DTXSID1037303)", "PFHXS (DTXSID7040150)", "PFHXA (DTXSID3031862)", "PFHPS (DTXSID8059920)", "PFNA (DTXSID8031863)", "PFDA (DTXSID3031860)"]{"allow-input":true}
#substanceCode = "me_egad_data:parameter." + substance + "_A"
dsstoxid = substance.split()[1].strip("()")
substanceCode ="dsstox:" + dsstoxid

# TODO: change the list of options to all subclasses of coso:MaterialSample
materialType = "   Surface Water Sample" # @param ["Water Sample", "   Surface Water Sample", "   Ground Water Sample", "   Drinking Water Sample", "Animal Material Sample", "Plant Material Sample", "Solid Material Sample" ]
#materialType = "SW (Surface Water)" # @param ["DW (Drinking Water)", "GW (Groundwater)", "WW (Waste Water)", "SW (Surface Water)", "PW (Pore Water)", "L (Leachate)", "SR (Storm Water Runoff)", "SL (Soil)" ]{"allow-input":true}
#matTypeCode = "me_egad_data:sampleMaterialType." + materialType.split()[0]
matTypeCode= "coso:"+ ''.join(materialType.split())

admin_region = "23005 (Cumberland County, Maine)" # @param ["23019 (Penobscot County, Maine)","23011 (Kennebec County, Maine)","23005 (Cumberland County, Maine)","23003 (Aroostook County, Maine)","23025 (Somerset County, Maine)","23 (Maine)"] {"allow-input":true}
regionCode = admin_region.split()[0]

minValue = 4 # @param
# maxValue = 1000000 # @param

# %% [markdown]
# ## Queries

# %%
# Query sample points, sample data, and S2 cells within a given administrative region

q1 = '''
PREFIX coso: <http://w3id.org/coso/v1/contaminoso#>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX hyf: <https://www.opengis.net/def/schema/hy_features/hyf/>
PREFIX kwg-ont: <http://stko-kwg.geog.ucsb.edu/lod/ontology/>
PREFIX kwgr: <http://stko-kwg.geog.ucsb.edu/lod/resource/>
PREFIX dsstox: <http://w3id.org/DSSTox/v1/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <https://schema.org/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX spatial: <http://purl.org/spatialai/spatial/spatial-full#>
PREFIX qudt: <http://qudt.org/schema/qudt/>

SELECT (COUNT(DISTINCT ?subVal) as ?resultCount) (MAX(?result_value) as ?max) ?sp ?spWKT ?s2cell WHERE {
    # ?sp rdf:type coso:SamplePoint ;
        geo:hasGeometry/geo:asWKT ?spWKT ;
        spatial:connectedTo ?ar3 ;
        spatial:connectedTo ?s2 .
    # ?ar3 rdf:type kwg-ont:AdministrativeRegion_3 ;
         kwg-ont:administrativePartOf+ kwgr:administrativeRegion.USA.''' + regionCode + ''' .
    # ?s2 rdf:type kwg-ont:S2Cell_Level13 .
    # ?s2cell rdf:type kwg-ont:S2Cell_Level13 ;
             kwg-ont:sfTouches | owl:sameAs ?s2 ;
             spatial:connectedTo ?waterbody .
    # ?waterbody a hyf:HY_WaterBody .
    # ?observation rdf:type coso:ContaminantObservation ;
                coso:observedAtSamplePoint ?sp ;
                coso:ofSubstance ?substance ;
                coso:analyzedSample ?sample ;
                coso:hasResult ?result .
    # ?sample rdfs:label ?sampleLabel ;
            rdf:type ?matType .
    # ?matType rdfs:label ?matTypeLabel .
    # ?result coso:measurementValue ?result_value ;
            coso:measurementUnit ?unit .
    # ?unit qudt:symbol ?unit_sym .
    VALUES ?unit {<http://qudt.org/vocab/unit/NanoGM-PER-L>}
    VALUES ?substance {''' + substanceCode + '''}
    VALUES ?matType {''' + matTypeCode + '''}
    FILTER (?result_value > '''+ str(minValue) + ''')
    BIND((CONCAT(str(?result_value) , " ", ?unit_sym)) as ?subVal)
} GROUP BY ?sp ?spWKT ?s2cell
'''
# print(q1)

sparqlGET.setQuery(q1)
samplepoint_result = sparqlGET.query()
samplepoints = convertToDataframe(samplepoint_result)

#s2_sp_values_string = convertS2ListToQueryString(samplepoints['s2cell'].tolist())

# %%
samplepoints
# Out:
#     resultCount    max                                                 sp  \
# 0             1   14.2  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 1             1   18.6  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 2             1   7.57  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 3             1   14.2  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 4             1   18.6  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 5             1   7.57  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 6             1   14.2  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 7             1   18.6  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 8             1   7.57  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 9             1   14.2  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 10            1   18.6  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 11            1   7.57  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 12            1   21.5  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 13            1  173.0  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 14            1   5.87  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 15            1   21.5  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 16            1  173.0  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 17            1   5.87  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
#
#                           spWKT  \
# 0   POINT(-70.410341 43.644329)
# 1   POINT(-70.408858 43.645348)
# 2   POINT(-70.408847 43.644141)
# 3   POINT(-70.410341 43.644329)
# 4   POINT(-70.408858 43.645348)
# 5   POINT(-70.408847 43.644141)
# 6   POINT(-70.410341 43.644329)
# 7   POINT(-70.408858 43.645348)
# 8   POINT(-70.408847 43.644141)
# 9   POINT(-70.410341 43.644329)
# 10  POINT(-70.408858 43.645348)
# 11  POINT(-70.408847 43.644141)
# 12  POINT(-70.283835 43.639128)
# 13  POINT(-70.285896 43.638296)
# 14  POINT(-70.283778 43.639248)
# 15  POINT(-70.283835 43.639128)
# 16  POINT(-70.285896 43.638296)
# 17  POINT(-70.283778 43.639248)
#
#                                                s2cell
# 0   http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 1   http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 2   http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 3   http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 4   http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 5   http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 6   http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 7   http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 8   http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 9   http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 10  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 11  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 12  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 13  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 14  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 15  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 16  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....
# 17  http://stko-kwg.geog.ucsb.edu/lod/resource/s2....

# %%
# Waterbodies for mapping
q_waterbodies = '''
PREFIX coso: <http://w3id.org/coso/v1/contaminoso#>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX hyf: <https://www.opengis.net/def/schema/hy_features/hyf/>
PREFIX kwg-ont: <http://stko-kwg.geog.ucsb.edu/lod/ontology/>
PREFIX kwgr: <http://stko-kwg.geog.ucsb.edu/lod/resource/>
PREFIX dsstox: <http://w3id.org/DSSTox/v1/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <https://schema.org/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX spatial: <http://purl.org/spatialai/spatial/spatial-full#>
PREFIX qudt: <http://qudt.org/schema/qudt/>

SELECT DISTINCT ?wb ?wb_name ?wbWKT #?s2wb
WHERE {
    # ?wb a hyf:HY_WaterBody ;
        geo:hasGeometry/geo:asWKT ?wbWKT ;
        spatial:connectedTo ?s2cell ;
        #spatial:connectedTo ?s2wb .
    #?s2wb a kwg-ont:S2Cell_Level13 .
    OPTIONAL { ?wb schema:name ?wb_name }
    # get s2cells of samples near water
    {SELECT DISTINCT ?s2cell WHERE {
    # ?sp rdf:type coso:SamplePoint ;
        spatial:connectedTo ?ar3 ;
        spatial:connectedTo ?s2 .
    # ?ar3 rdf:type kwg-ont:AdministrativeRegion_3 ;
         kwg-ont:administrativePartOf+ kwgr:administrativeRegion.USA.''' + regionCode + ''' .
    # ?s2 rdf:type kwg-ont:S2Cell_Level13 .
    # ?s2cell rdf:type kwg-ont:S2Cell_Level13 ;
             kwg-ont:sfTouches | owl:sameAs ?s2 ;
             spatial:connectedTo ?waterbody .
    # ?waterbody a hyf:HY_WaterBody .
    # ?observation rdf:type coso:ContaminantObservation ;
                coso:observedAtSamplePoint ?sp ;
                coso:ofSubstance ?substance ;
                coso:analyzedSample ?sample ;
                coso:hasResult ?result .
    # ?sample rdfs:label ?sampleLabel ;
            rdf:type ?matType .
    # ?matType rdfs:label ?matTypeLabel .
    # ?result coso:measurementValue ?result_value ;
            coso:measurementUnit ?unit .
    # ?unit qudt:symbol ?unit_sym .
    VALUES ?unit {<http://qudt.org/vocab/unit/NanoGM-PER-L>}
    VALUES ?substance {''' + substanceCode + '''}
    VALUES ?matType {''' + matTypeCode + '''}
    FILTER (?result_value > '''+ str(minValue) + ''')
  } GROUP BY ?s2cell}
}
'''

sparqlGET.setQuery(q_waterbodies)
waterbodies_result = sparqlGET.query()
waterbodies = convertToDataframe(waterbodies_result)

#s2_wb_values_string = convertS2ListToQueryString(waterbodies['s2wb'].tolist())

# %%
waterbodies
# Out:
#                                              wb  \
# 0  https://geoconnex.us/nhdplusv2/comid/6720129
# 1  https://geoconnex.us/nhdplusv2/comid/6720137
# 2  https://geoconnex.us/nhdplusv2/comid/6720139
# 3  https://geoconnex.us/nhdplusv2/comid/6720153
# 4  https://geoconnex.us/nhdplusv2/comid/6720169
#
#                                                wbWKT
# 0  POLYGON ((-70.40314880116023 43.64426313225539...
# 1  POLYGON ((-70.3898278678476 43.64035599892816,...
# 2  POLYGON ((-70.39212566784403 43.63827473226468...
# 3  POLYGON ((-70.39681520117006 43.63429499893755...
# 4  POLYGON ((-70.27834986802065 43.62966493227805...

# %%
# Query the hydrology graph for the upstream S2cells

q2 = '''
PREFIX coso: <http://w3id.org/coso/v1/contaminoso#>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX hyf: <https://www.opengis.net/def/schema/hy_features/hyf/>
PREFIX kwg-ont: <http://stko-kwg.geog.ucsb.edu/lod/ontology/>
PREFIX kwgr: <http://stko-kwg.geog.ucsb.edu/lod/resource/>
PREFIX dsstox: <http://w3id.org/DSSTox/v1/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <https://schema.org/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX spatial: <http://purl.org/spatialai/spatial/spatial-full#>
PREFIX qudt: <http://qudt.org/schema/qudt/>
PREFIX nhdplusv2: <http://nhdplusv2.spatialai.org/v1/nhdplusv2#>

SELECT DISTINCT ?upstream_flowline ?us_ftype ?upstream_flowlineWKT #?downstream_flowline ?ds_ftype
WHERE {
	{SELECT DISTINCT ?s2wb WHERE {																# get s2 of water bodies that overlap...
    # ?wb a hyf:HY_WaterBody ;
        geo:hasGeometry/geo:asWKT ?wbWKT ;
        spatial:connectedTo ?s2cell ;
        spatial:connectedTo ?s2wb .
    # ?s2wb a kwg-ont:S2Cell_Level13 .
						{SELECT DISTINCT ?s2cell WHERE { 										# s2cells of samples near water
						# ?sp rdf:type coso:SamplePoint ;
								spatial:connectedTo ?ar3 ;
								spatial:connectedTo ?s2 .
						# ?ar3 rdf:type kwg-ont:AdministrativeRegion_3 ;
								kwg-ont:administrativePartOf+ kwgr:administrativeRegion.USA.''' + regionCode + ''' .
						# ?s2 rdf:type kwg-ont:S2Cell_Level13 .
						# ?s2cell rdf:type kwg-ont:S2Cell_Level13 ;
										kwg-ont:sfTouches | owl:sameAs ?s2 ;
										spatial:connectedTo ?waterbody .
						# ?waterbody a hyf:HY_WaterBody .
						# ?observation rdf:type coso:ContaminantObservation ;
												coso:observedAtSamplePoint ?sp ;
												coso:ofSubstance ?substance ;
												coso:analyzedSample ?sample ;
												coso:hasResult ?result .
						# ?sample rdfs:label ?sampleLabel ;
										rdf:type ?matType .
						# ?matType rdfs:label ?matTypeLabel .
						# ?result coso:measurementValue ?result_value ;
										coso:measurementUnit ?unit .
						# ?unit qudt:symbol ?unit_sym .
						VALUES ?unit {<http://qudt.org/vocab/unit/NanoGM-PER-L>}
						VALUES ?substance {''' + substanceCode + '''}
						VALUES ?matType {''' + matTypeCode + '''}
						FILTER (?result_value > '''+ str(minValue) + ''')
					} GROUP BY ?s2cell}
		}}
	# ?downstream_flowline rdf:type hyf:HY_FlowPath ;							# ... and flowlines connected to
						 spatial:connectedTo ?s2wb ;
						 nhdplusv2:hasFTYPE ?ds_ftype .
	# ?upstream_flowline hyf:downstreamFlowPathTC ?downstream_flowline ;   # and their upstream parts
					   geo:hasGeometry/geo:asWKT ?upstream_flowlineWKT ;
					   nhdplusv2:hasFTYPE ?us_ftype .
	#?s2fl spatial:connectedTo ?upstream_flowline ;
	#		rdf:type kwg-ont:S2Cell_Level13 .
}
'''

sparqlGET.setQuery(q2)
hydrology_result = sparqlGET.query()
hydrology = convertToDataframe(hydrology_result)

#s2_fl_values_string = convertS2ListToQueryString(hydrology['s2cell'].tolist())

# %%
hydrology
# Out:
#                                upstream_flowline        us_ftype  \
# 0   https://geoconnex.us/nhdplusv2/comid/6721543     StreamRiver
# 1   https://geoconnex.us/nhdplusv2/comid/6721551     StreamRiver
# 2   https://geoconnex.us/nhdplusv2/comid/6721565     StreamRiver
# 3   https://geoconnex.us/nhdplusv2/comid/6721567     StreamRiver
# 4   https://geoconnex.us/nhdplusv2/comid/6721569     StreamRiver
# 5   https://geoconnex.us/nhdplusv2/comid/6721571     StreamRiver
# 6   https://geoconnex.us/nhdplusv2/comid/6721573     StreamRiver
# 7   https://geoconnex.us/nhdplusv2/comid/6721575     StreamRiver
# 8   https://geoconnex.us/nhdplusv2/comid/6721577     StreamRiver
# 9   https://geoconnex.us/nhdplusv2/comid/6721579     StreamRiver
# 10  https://geoconnex.us/nhdplusv2/comid/6721581     StreamRiver
# 11  https://geoconnex.us/nhdplusv2/comid/6721599     StreamRiver
# 12  https://geoconnex.us/nhdplusv2/comid/6721601     StreamRiver
# 13  https://geoconnex.us/nhdplusv2/comid/6721603     StreamRiver
# 14  https://geoconnex.us/nhdplusv2/comid/6721605     StreamRiver
# 15  https://geoconnex.us/nhdplusv2/comid/6721607     StreamRiver
# 16  https://geoconnex.us/nhdplusv2/comid/6721609     StreamRiver
# 17  https://geoconnex.us/nhdplusv2/comid/6721619     StreamRiver
# 18  https://geoconnex.us/nhdplusv2/comid/6721621     StreamRiver
# 19  https://geoconnex.us/nhdplusv2/comid/6721633     StreamRiver
# 20  https://geoconnex.us/nhdplusv2/comid/6721635     StreamRiver
# 21  https://geoconnex.us/nhdplusv2/comid/6721641     StreamRiver
# 22  https://geoconnex.us/nhdplusv2/comid/6721647     StreamRiver
# 23  https://geoconnex.us/nhdplusv2/comid/6721649     StreamRiver
# 24  https://geoconnex.us/nhdplusv2/comid/6721655     StreamRiver
# 25  https://geoconnex.us/nhdplusv2/comid/6721669     StreamRiver
# 26  https://geoconnex.us/nhdplusv2/comid/6721675     StreamRiver
# 27  https://geoconnex.us/nhdplusv2/comid/6721677     StreamRiver
# 28  https://geoconnex.us/nhdplusv2/comid/6721679     StreamRiver
# 29  https://geoconnex.us/nhdplusv2/comid/6721681     StreamRiver
# 30  https://geoconnex.us/nhdplusv2/comid/6721689     StreamRiver
# 31  https://geoconnex.us/nhdplusv2/comid/6721703     StreamRiver
# 32  https://geoconnex.us/nhdplusv2/comid/6721717     StreamRiver
# 33  https://geoconnex.us/nhdplusv2/comid/6721719     StreamRiver
# 34  https://geoconnex.us/nhdplusv2/comid/6721737     StreamRiver
# 35  https://geoconnex.us/nhdplusv2/comid/6721951     StreamRiver
# 36  https://geoconnex.us/nhdplusv2/comid/6721953     StreamRiver
# 37  https://geoconnex.us/nhdplusv2/comid/6721989     StreamRiver
# 38  https://geoconnex.us/nhdplusv2/comid/6722431  ArtificialPath
# 39  https://geoconnex.us/nhdplusv2/comid/6722473  ArtificialPath
# 40  https://geoconnex.us/nhdplusv2/comid/6722539  ArtificialPath
# 41  https://geoconnex.us/nhdplusv2/comid/6722543  ArtificialPath
# 42  https://geoconnex.us/nhdplusv2/comid/6722649       Connector
# 43  https://geoconnex.us/nhdplusv2/comid/6722651  ArtificialPath
# 44  https://geoconnex.us/nhdplusv2/comid/6722653       Connector
#
#                                  upstream_flowlineWKT
# 0   LINESTRING (-70.39310646784253 43.650965532244...
# 1   LINESTRING (-70.4851554676996 43.6505437989123...
# 2   LINESTRING (-70.43874500110502 43.657120932235...
# 3   LINESTRING (-70.4509240010861 43.6734621988767...
# 4   LINESTRING (-70.42496820112638 43.642128132258...
# 5   LINESTRING (-70.42871486778722 43.641920532259...
# 6   LINESTRING (-70.43370626777948 43.657604132234...
# 7   LINESTRING (-70.48067846770658 43.647689998916...
# 8   LINESTRING (-70.44004640110296 43.638644332264...
# 9   LINESTRING (-70.44745320109149 43.644767598921...
# 10  LINESTRING (-70.46066946773766 43.638926998930...
# 11  LINESTRING (-70.4589724010736 43.6195147989604...
# 12  LINESTRING (-70.4041786678253 43.6277075322810...
# 13  LINESTRING (-70.28931720133693 43.620983598958...
# 14  LINESTRING (-70.42963746778582 43.619305132294...
# 15  LINESTRING (-70.41518926780822 43.617756732296...
# 16  LINESTRING (-70.29637226799264 43.617466932297...
# 17  LINESTRING (-70.41562580114089 43.612245732305...
# 18  LINESTRING (-70.30471600131301 43.614933798967...
# 19  LINESTRING (-70.44312420109821 43.605828998981...
# 20  LINESTRING (-70.49662040101515 43.606308598981...
# 21  LINESTRING (-70.42531300112586 43.605472998982...
# 22  LINESTRING (-70.44755320109135 43.599514998991...
# 23  LINESTRING (-70.44481500109555 43.598807932325...
# 24  LINESTRING (-70.43668666777484 43.589003132341...
# 25  LINESTRING (-70.46565380106324 43.584706799014...
# 26  LINESTRING (-70.494145601019 43.59631873232985...
# 27  LINESTRING (-70.4709554677217 43.5950151323318...
# 28  LINESTRING (-70.4738586010505 43.5814985323528...
# 29  LINESTRING (-70.47090106772174 43.581089532353...
# 30  LINESTRING (-70.49717386768094 43.584950932347...
# 31  LINESTRING (-70.45148726775187 43.576439999027...
# 32  LINESTRING (-70.48657720103074 43.570579132369...
# 33  LINESTRING (-70.48685986769698 43.570395932370...
# 34  LINESTRING (-70.45521240107945 43.563471999047...
# 35  LINESTRING (-70.50015460100968 43.629545532278...
# 36  LINESTRING (-70.5272580009676 43.6097003323090...
# 37  LINESTRING (-70.47448806771621 43.563136199048...
# 38  LINESTRING (-70.4809310677062 43.6480555322495...
# 39  LINESTRING (-70.45683186774357 43.552128999065...
# 40  LINESTRING (-70.41449240114264 43.611605932306...
# 41  LINESTRING (-70.4880204010285 43.5687027323726...
# 42  LINESTRING (-70.27311660136206 43.634165398937...
# 43  LINESTRING (-70.27834986802065 43.629664932278...
# 44  LINESTRING (-70.2783824013539 43.6289103322792...

# %%
# Retrieve facility details
q3 = '''
PREFIX coso: <http://w3id.org/coso/v1/contaminoso#>
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX hyf: <https://www.opengis.net/def/schema/hy_features/hyf/>
PREFIX kwg-ont: <http://stko-kwg.geog.ucsb.edu/lod/ontology/>
PREFIX kwgr: <http://stko-kwg.geog.ucsb.edu/lod/resource/>
PREFIX dsstox: <http://w3id.org/DSSTox/v1/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX schema: <https://schema.org/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX spatial: <http://purl.org/spatialai/spatial/spatial-full#>
PREFIX qudt: <http://qudt.org/schema/qudt/>
PREFIX nhdplusv2: <http://nhdplusv2.spatialai.org/v1/nhdplusv2#>
PREFIX fio: <http://w3id.org/fio/v1/fio#>
PREFIX naics: <http://w3id.org/fio/v1/naics#>

SELECT DISTINCT ?facility ?facWKT ?facilityName ?industry ?industryName ?industryGroupCode ?industryGroupName ?industrySubsectorCode ?industrySubsectorName WHERE {
      {SELECT DISTINCT ?s2fl WHERE {
          {SELECT DISTINCT ?s2wb WHERE {																# get s2 of water bodies that overlap...
            # ?wb a hyf:HY_WaterBody ;
                geo:hasGeometry/geo:asWKT ?wbWKT ;
                spatial:connectedTo ?s2cell ;
                spatial:connectedTo ?s2wb .
            # ?s2wb a kwg-ont:S2Cell_Level13 .
                    {SELECT DISTINCT ?s2cell WHERE { 										# s2cells of samples near water
                    # ?sp rdf:type coso:SamplePoint ;
                        spatial:connectedTo ?ar3 ;
                        spatial:connectedTo ?s2 .
                    # ?ar3 rdf:type kwg-ont:AdministrativeRegion_3 ;
                        kwg-ont:administrativePartOf+ kwgr:administrativeRegion.USA.''' + regionCode + ''' .
                    # ?s2 rdf:type kwg-ont:S2Cell_Level13 .
                    # ?s2cell rdf:type kwg-ont:S2Cell_Level13 ;
                            kwg-ont:sfTouches | owl:sameAs ?s2 ;
                            spatial:connectedTo ?waterbody .
                    # ?waterbody a hyf:HY_WaterBody .
                    # ?observation rdf:type coso:ContaminantObservation ;
                                coso:observedAtSamplePoint ?sp ;
                                coso:ofSubstance ?substance ;
                                coso:analyzedSample ?sample ;
                                coso:hasResult ?result .
                    # ?sample rdfs:label ?sampleLabel ;
                            rdf:type ?matType .
                    # ?matType rdfs:label ?matTypeLabel .
                    # ?result coso:measurementValue ?result_value ;
                            coso:measurementUnit ?unit .
                    # ?unit qudt:symbol ?unit_sym .
                    VALUES ?unit {<http://qudt.org/vocab/unit/NanoGM-PER-L>}
                    VALUES ?substance {''' + substanceCode + '''}
                    VALUES ?matType {''' + matTypeCode + '''}
                    FILTER (?result_value > '''+ str(minValue) + ''')
                  } GROUP BY ?s2cell}
            }}
          # ?downstream_flowline rdf:type hyf:HY_FlowPath ;							# ... and flowlines connected to
                    spatial:connectedTo ?s2wb ;
                    nhdplusv2:hasFTYPE ?ds_ftype .
          # ?upstream_flowline hyf:downstreamFlowPathTC ?downstream_flowline ;   # and their upstream parts
                    geo:hasGeometry/geo:asWKT ?upstream_flowlineWKT ;
                    nhdplusv2:hasFTYPE ?us_ftype .
          # ?s2fl spatial:connectedTo ?upstream_flowline ;
          		rdf:type kwg-ont:S2Cell_Level13 .
        }}

    # ?s2fl kwg-ont:sfContains ?facility.
    # ?facility fio:ofIndustry ?industryCode, ?industryGroupCode, ?industrySubsectorCode ;
              geo:hasGeometry/geo:asWKT ?facWKT;
              rdfs:label ?facilityName.
    # ?industryCode a naics:NAICS-IndustryCode;
                  rdfs:label ?industryName ;
    fio:subcodeOf ?industryGroupCode .
    # ?industryGroupCode a naics:NAICS-IndustryGroup;
                       rdfs:label ?industryGroupName ;
                       fio:subcodeOf ?industrySubsectorCode .
    # ?industrySubsectorCode a naics:NAICS-IndustrySubsector;
                           rdfs:label ?industrySubsectorName;
                           fio:subcodeOf ?manufacturing.
  VALUES ?manufacturing {naics:NAICS-31 naics:NAICS-32 naics:NAICS-33} .
}
'''

sparqlGET.setQuery(q3)
facility_result = sparqlGET.query()
facilities = convertToDataframe(facility_result)

# %%
facilities
# Out:
#                                              facility  \
# 0   http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 1   http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 2   http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 3   http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 4   http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 5   http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 6   http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 7   http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 8   http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 9   http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 10  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 11  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 12  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 13  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 14  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 15  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 16  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 17  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 18  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 19  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 20  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 21  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 22  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 23  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 24  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 25  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
# 26  http://w3id.org/fio/v1/epa-frs-data#d.FRS-Faci...
#
#                          facWKT  \
# 0   POINT(-70.279970 43.628330)
# 1   POINT(-70.279970 43.628330)
# 2   POINT(-70.304440 43.613220)
# 3   POINT(-70.304440 43.613220)
# 4   POINT(-70.304440 43.613220)
# 5   POINT(-70.304440 43.613220)
# 6   POINT(-70.304440 43.613220)
# 7   POINT(-70.304440 43.613220)
# 8   POINT(-70.399546 43.645162)
# 9   POINT(-70.399546 43.645162)
# 10  POINT(-70.306110 43.614300)
# 11  POINT(-70.306110 43.614300)
# 12  POINT(-70.306110 43.614300)
# 13  POINT(-70.268540 43.637610)
# 14  POINT(-70.268540 43.637610)
# 15  POINT(-70.276820 43.642510)
# 16  POINT(-70.276820 43.642510)
# 17  POINT(-70.287670 43.624170)
# 18  POINT(-70.304440 43.613220)
# 19  POINT(-70.304440 43.613220)
# 20  POINT(-70.290690 43.621030)
# 21  POINT(-70.304440 43.613220)
# 22  POINT(-70.304440 43.613220)
# 23  POINT(-70.304440 43.613220)
# 24  POINT(-70.304440 43.613220)
# 25  POINT(-70.461452 43.669157)
# 26  POINT(-70.461452 43.669157)
#
#                                          facilityName  \
# 0                               MEGQUIRE & JONES CORP
# 1                               MEGQUIRE & JONES CORP
# 2                        EAST COAST STEEL, BRIDGE DIV
# 3                        EAST COAST STEEL, BRIDGE DIV
# 4       DURASTONE PRECAST INCORPORATED-SOUTH PORTLAND
# 5       DURASTONE PRECAST INCORPORATED-SOUTH PORTLAND
# 6       DURASTONE PRECAST INCORPORATED-SOUTH PORTLAND
# 7       DURASTONE PRECAST INCORPORATED-SOUTH PORTLAND
# 8                               MAINE RUBBER RIM SHOP
# 9                               MAINE RUBBER RIM SHOP
# 10                             POND COVE MILLWORK INC
# 11                             POND COVE MILLWORK INC
# 12                             POND COVE MILLWORK INC
# 13                                 TURNERS ISLAND LLC
# 14                                 TURNERS ISLAND LLC
# 15                   CIANBRO HORNBECK MPSV CONVERSION
# 16                   CIANBRO HORNBECK MPSV CONVERSION
# 17                                      GROW-TECH LLC
# 18                   CASCO BAY STEEL STRUCTURES, INC.
# 19                   CASCO BAY STEEL STRUCTURES, INC.
# 20  INLAND FRESH SEAFOOD CORPORATION OF AMERICA, INC.
# 21                       NEW ENGLAND INSPECTION, INC.
# 22                       NEW ENGLAND INSPECTION, INC.
# 23                                    CASCO BAY STEEL
# 24                                    CASCO BAY STEEL
# 25                              HELICAL SOLUTIONS LLC
# 26                              HELICAL SOLUTIONS LLC
#
#                                          industryName  \
# 0          Fabricated Structural Metal Manufacturing
# 1   Plate Work and Fabricated Structural Product M...
# 2          Fabricated Structural Metal Manufacturing
# 3   Plate Work and Fabricated Structural Product M...
# 4             Concrete Block and Brick Manufacturing
# 5       Concrete Pipe, Brick, and Block Manufacturing
# 6          Fabricated Structural Metal Manufacturing
# 7   Plate Work and Fabricated Structural Product M...
# 8           All Other Plastics Product Manufacturing
# 9                Other Plastics Product Manufacturing
# 10                                           Millwork
# 11               Other Millwork (including Flooring)
# 12  Wood Kitchen Cabinet and Countertop Manufacturing
# 13                             Ship and Boat Building
# 14                       Ship Building and Repairing
# 15  Mining and Oil and Gas Field Machinery Manufac...
# 16  Oil and Gas Field Machinery and Equipment Manu...
# 17  Urethane and Other Foam Product (except Polyst...
# 18         Fabricated Structural Metal Manufacturing
# 19  Plate Work and Fabricated Structural Product M...
# 20          Seafood Product Preparation and Packaging
# 21         Fabricated Structural Metal Manufacturing
# 22  Plate Work and Fabricated Structural Product M...
# 23         Fabricated Structural Metal Manufacturing
# 24  Plate Work and Fabricated Structural Product M...
# 25  Cutting Tool and Machine Tool Accessory Manufa...
# 26               Metalworking Machinery Manufacturing
#
#                           industryGroupCode  \
# 0   http://w3id.org/fio/v1/naics#NAICS-3323
# 1   http://w3id.org/fio/v1/naics#NAICS-3323
# 2   http://w3id.org/fio/v1/naics#NAICS-3323
# 3   http://w3id.org/fio/v1/naics#NAICS-3323
# 4   http://w3id.org/fio/v1/naics#NAICS-3273
# 5   http://w3id.org/fio/v1/naics#NAICS-3273
# 6   http://w3id.org/fio/v1/naics#NAICS-3323
# 7   http://w3id.org/fio/v1/naics#NAICS-3323
# 8   http://w3id.org/fio/v1/naics#NAICS-3261
# 9   http://w3id.org/fio/v1/naics#NAICS-3261
# 10  http://w3id.org/fio/v1/naics#NAICS-3219
# 11  http://w3id.org/fio/v1/naics#NAICS-3219
# 12  http://w3id.org/fio/v1/naics#NAICS-3371
# 13  http://w3id.org/fio/v1/naics#NAICS-3366
# 14  http://w3id.org/fio/v1/naics#NAICS-3366
# 15  http://w3id.org/fio/v1/naics#NAICS-3331
# 16  http://w3id.org/fio/v1/naics#NAICS-3331
# 17  http://w3id.org/fio/v1/naics#NAICS-3261
# 18  http://w3id.org/fio/v1/naics#NAICS-3323
# 19  http://w3id.org/fio/v1/naics#NAICS-3323
# 20  http://w3id.org/fio/v1/naics#NAICS-3117
# 21  http://w3id.org/fio/v1/naics#NAICS-3323
# 22  http://w3id.org/fio/v1/naics#NAICS-3323
# 23  http://w3id.org/fio/v1/naics#NAICS-3323
# 24  http://w3id.org/fio/v1/naics#NAICS-3323
# 25  http://w3id.org/fio/v1/naics#NAICS-3335
# 26  http://w3id.org/fio/v1/naics#NAICS-3335
#
#                                     industryGroupName  \
# 0   Architectural and Structural Metals Manufacturing
# 1   Architectural and Structural Metals Manufacturing
# 2   Architectural and Structural Metals Manufacturing
# 3   Architectural and Structural Metals Manufacturing
# 4           Cement and Concrete Product Manufacturing
# 5           Cement and Concrete Product Manufacturing
# 6   Architectural and Structural Metals Manufacturing
# 7   Architectural and Structural Metals Manufacturing
# 8                      Plastics Product Manufacturing
# 9                      Plastics Product Manufacturing
# 10                   Other Wood Product Manufacturing
# 11                   Other Wood Product Manufacturing
# 12  Household and Institutional Furniture and Kitc...
# 13                             Ship and Boat Building
# 14                             Ship and Boat Building
# 15  Agriculture, Construction, and Mining Machiner...
# 16  Agriculture, Construction, and Mining Machiner...
# 17                     Plastics Product Manufacturing
# 18  Architectural and Structural Metals Manufacturing
# 19  Architectural and Structural Metals Manufacturing
# 20          Seafood Product Preparation and Packaging
# 21  Architectural and Structural Metals Manufacturing
# 22  Architectural and Structural Metals Manufacturing
# 23  Architectural and Structural Metals Manufacturing
# 24  Architectural and Structural Metals Manufacturing
# 25               Metalworking Machinery Manufacturing
# 26               Metalworking Machinery Manufacturing
#
#                      industrySubsectorCode  \
# 0   http://w3id.org/fio/v1/naics#NAICS-332
# 1   http://w3id.org/fio/v1/naics#NAICS-332
# 2   http://w3id.org/fio/v1/naics#NAICS-332
# 3   http://w3id.org/fio/v1/naics#NAICS-332
# 4   http://w3id.org/fio/v1/naics#NAICS-327
# 5   http://w3id.org/fio/v1/naics#NAICS-327
# 6   http://w3id.org/fio/v1/naics#NAICS-332
# 7   http://w3id.org/fio/v1/naics#NAICS-332
# 8   http://w3id.org/fio/v1/naics#NAICS-326
# 9   http://w3id.org/fio/v1/naics#NAICS-326
# 10  http://w3id.org/fio/v1/naics#NAICS-321
# 11  http://w3id.org/fio/v1/naics#NAICS-321
# 12  http://w3id.org/fio/v1/naics#NAICS-337
# 13  http://w3id.org/fio/v1/naics#NAICS-336
# 14  http://w3id.org/fio/v1/naics#NAICS-336
# 15  http://w3id.org/fio/v1/naics#NAICS-333
# 16  http://w3id.org/fio/v1/naics#NAICS-333
# 17  http://w3id.org/fio/v1/naics#NAICS-326
# 18  http://w3id.org/fio/v1/naics#NAICS-332
# 19  http://w3id.org/fio/v1/naics#NAICS-332
# 20  http://w3id.org/fio/v1/naics#NAICS-311
# 21  http://w3id.org/fio/v1/naics#NAICS-332
# 22  http://w3id.org/fio/v1/naics#NAICS-332
# 23  http://w3id.org/fio/v1/naics#NAICS-332
# 24  http://w3id.org/fio/v1/naics#NAICS-332
# 25  http://w3id.org/fio/v1/naics#NAICS-333
# 26  http://w3id.org/fio/v1/naics#NAICS-333
#
#                           industrySubsectorName
# 0        Fabricated Metal Product Manufacturing
# 1        Fabricated Metal Product Manufacturing
# 2        Fabricated Metal Product Manufacturing
# 3        Fabricated Metal Product Manufacturing
# 4     Nonmetallic Mineral Product Manufacturing
# 5     Nonmetallic Mineral Product Manufacturing
# 6        Fabricated Metal Product Manufacturing
# 7        Fabricated Metal Product Manufacturing
# 8    Plastics and Rubber Products Manufacturing
# 9    Plastics and Rubber Products Manufacturing
# 10                   Wood Product Manufacturing
# 11                   Wood Product Manufacturing
# 12  Furniture and Related Product Manufacturing
# 13       Transportation Equipment Manufacturing
# 14       Transportation Equipment Manufacturing
# 15                      Machinery Manufacturing
# 16                      Machinery Manufacturing
# 17   Plastics and Rubber Products Manufacturing
# 18       Fabricated Metal Product Manufacturing
# 19       Fabricated Metal Product Manufacturing
# 20                           Food Manufacturing
# 21       Fabricated Metal Product Manufacturing
# 22       Fabricated Metal Product Manufacturing
# 23       Fabricated Metal Product Manufacturing
# 24       Fabricated Metal Product Manufacturing
# 25                      Machinery Manufacturing
# 26                      Machinery Manufacturing

# %%
# County boundaries for mapping
q_counties = '''
PREFIX geo: <http://www.opengis.net/ont/geosparql#>
PREFIX kwgr: <http://stko-kwg.geog.ucsb.edu/lod/resource/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT * WHERE {
    # ?county geo:hasGeometry/geo:asWKT ?countyWKT ;
            rdfs:label ?countyName.
    VALUES ?county {kwgr:administrativeRegion.USA.'''+ regionCode + '''}
}
'''

sparqlGET.setQuery(q_counties)
counties_result = sparqlGET.query()
counties = convertToDataframe(counties_result)

# %% [markdown]
# ## Prep data for mapping

# %%
samplept_columns = ['resultCount', 'max', 'sp', 'spWKT']
samplept_map = samplepoints[samplept_columns].copy()
samplept_map.drop_duplicates(inplace=True)
samplept_map['spWKT'] = samplept_map['spWKT'].apply(wkt.loads)
samplept_map = gpd.GeoDataFrame(samplept_map, geometry='spWKT')
samplept_map.set_crs(epsg=4326, inplace=True, allow_override=True)
# Out:
#     resultCount    max                                                 sp  \
# 0             1   14.2  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 1             1   18.6  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 2             1   7.57  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 12            1   21.5  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 13            1  173.0  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
# 14            1   5.87  http://w3id.org/sawgraph/v1/me-egad-data#sampl...
#
#                          spWKT
# 0   POINT (-70.41034 43.64433)
# 1   POINT (-70.40886 43.64535)
# 2   POINT (-70.40885 43.64414)
# 12  POINT (-70.28384 43.63913)
# 13    POINT (-70.2859 43.6383)
# 14  POINT (-70.28378 43.63925)

# %%
waterbody_columns = ['wb', 'wb_name', 'wbWKT']
waterbodies.drop_duplicates(inplace=True)
waterbodies['wbWKT'] = waterbodies['wbWKT'].apply(wkt.loads)
waterbodies = gpd.GeoDataFrame(waterbodies, geometry='wbWKT')
waterbodies.set_crs(epsg=4326, inplace=True, allow_override=True)
# Out:
#                                              wb  \
# 0  https://geoconnex.us/nhdplusv2/comid/6720129
# 1  https://geoconnex.us/nhdplusv2/comid/6720137
# 2  https://geoconnex.us/nhdplusv2/comid/6720139
# 3  https://geoconnex.us/nhdplusv2/comid/6720153
# 4  https://geoconnex.us/nhdplusv2/comid/6720169
#
#                                                wbWKT
# 0  POLYGON ((-70.40315 43.64426, -70.40482 43.645...
# 1  POLYGON ((-70.38983 43.64036, -70.39102 43.641...
# 2  POLYGON ((-70.39213 43.63827, -70.39263 43.638...
# 3  POLYGON ((-70.39682 43.63429, -70.3977 43.6351...
# 4  POLYGON ((-70.27835 43.62966, -70.2786 43.6299...

# %%
facilities.drop_duplicates(inplace=True)
facilities['facWKT'] = facilities['facWKT'].apply(wkt.loads)
facilities = gpd.GeoDataFrame(facilities, geometry='facWKT')
facilities.set_crs(epsg=4326, inplace=True, allow_override=True)
facilities['industryGroupCode'] = facilities['industryGroupCode'].apply(lambda x: x.split('#')[-1])
facilities['industrySubsectorCode'] = facilities['industrySubsectorCode'].apply(lambda x: x.split('#')[-1])

# %%
hydrology_columns = ['upstream_flowline', 'us_ftype', 'upstream_flowlineWKT']
hydrology['upstream_flowlineWKT'] = hydrology['upstream_flowlineWKT'].apply(wkt.loads)
hydrology.drop_duplicates(inplace=True)
hydrology = gpd.GeoDataFrame(hydrology, geometry='upstream_flowlineWKT')
hydrology.set_crs(epsg=4326, inplace=True, allow_override=True)
# Out:
#                                upstream_flowline        us_ftype  \
# 0   https://geoconnex.us/nhdplusv2/comid/6721543     StreamRiver
# 1   https://geoconnex.us/nhdplusv2/comid/6721551     StreamRiver
# 2   https://geoconnex.us/nhdplusv2/comid/6721565     StreamRiver
# 3   https://geoconnex.us/nhdplusv2/comid/6721567     StreamRiver
# 4   https://geoconnex.us/nhdplusv2/comid/6721569     StreamRiver
# 5   https://geoconnex.us/nhdplusv2/comid/6721571     StreamRiver
# 6   https://geoconnex.us/nhdplusv2/comid/6721573     StreamRiver
# 7   https://geoconnex.us/nhdplusv2/comid/6721575     StreamRiver
# 8   https://geoconnex.us/nhdplusv2/comid/6721577     StreamRiver
# 9   https://geoconnex.us/nhdplusv2/comid/6721579     StreamRiver
# 10  https://geoconnex.us/nhdplusv2/comid/6721581     StreamRiver
# 11  https://geoconnex.us/nhdplusv2/comid/6721599     StreamRiver
# 12  https://geoconnex.us/nhdplusv2/comid/6721601     StreamRiver
# 13  https://geoconnex.us/nhdplusv2/comid/6721603     StreamRiver
# 14  https://geoconnex.us/nhdplusv2/comid/6721605     StreamRiver
# 15  https://geoconnex.us/nhdplusv2/comid/6721607     StreamRiver
# 16  https://geoconnex.us/nhdplusv2/comid/6721609     StreamRiver
# 17  https://geoconnex.us/nhdplusv2/comid/6721619     StreamRiver
# 18  https://geoconnex.us/nhdplusv2/comid/6721621     StreamRiver
# 19  https://geoconnex.us/nhdplusv2/comid/6721633     StreamRiver
# 20  https://geoconnex.us/nhdplusv2/comid/6721635     StreamRiver
# 21  https://geoconnex.us/nhdplusv2/comid/6721641     StreamRiver
# 22  https://geoconnex.us/nhdplusv2/comid/6721647     StreamRiver
# 23  https://geoconnex.us/nhdplusv2/comid/6721649     StreamRiver
# 24  https://geoconnex.us/nhdplusv2/comid/6721655     StreamRiver
# 25  https://geoconnex.us/nhdplusv2/comid/6721669     StreamRiver
# 26  https://geoconnex.us/nhdplusv2/comid/6721675     StreamRiver
# 27  https://geoconnex.us/nhdplusv2/comid/6721677     StreamRiver
# 28  https://geoconnex.us/nhdplusv2/comid/6721679     StreamRiver
# 29  https://geoconnex.us/nhdplusv2/comid/6721681     StreamRiver
# 30  https://geoconnex.us/nhdplusv2/comid/6721689     StreamRiver
# 31  https://geoconnex.us/nhdplusv2/comid/6721703     StreamRiver
# 32  https://geoconnex.us/nhdplusv2/comid/6721717     StreamRiver
# 33  https://geoconnex.us/nhdplusv2/comid/6721719     StreamRiver
# 34  https://geoconnex.us/nhdplusv2/comid/6721737     StreamRiver
# 35  https://geoconnex.us/nhdplusv2/comid/6721951     StreamRiver
# 36  https://geoconnex.us/nhdplusv2/comid/6721953     StreamRiver
# 37  https://geoconnex.us/nhdplusv2/comid/6721989     StreamRiver
# 38  https://geoconnex.us/nhdplusv2/comid/6722431  ArtificialPath
# 39  https://geoconnex.us/nhdplusv2/comid/6722473  ArtificialPath
# 40  https://geoconnex.us/nhdplusv2/comid/6722539  ArtificialPath
# 41  https://geoconnex.us/nhdplusv2/comid/6722543  ArtificialPath
# 42  https://geoconnex.us/nhdplusv2/comid/6722649       Connector
# 43  https://geoconnex.us/nhdplusv2/comid/6722651  ArtificialPath
# 44  https://geoconnex.us/nhdplusv2/comid/6722653       Connector
#
#                                  upstream_flowlineWKT
# 0   LINESTRING (-70.39311 43.65097, -70.39355 43.6...
# 1   LINESTRING (-70.48516 43.65054, -70.48412 43.6...
# 2   LINESTRING (-70.43875 43.65712, -70.43884 43.6...
# 3   LINESTRING (-70.45092 43.67346, -70.45061 43.6...
# 4   LINESTRING (-70.42497 43.64213, -70.42462 43.6...
# 5   LINESTRING (-70.42871 43.64192, -70.42837 43.6...
# 6   LINESTRING (-70.43371 43.6576, -70.43279 43.65...
# 7   LINESTRING (-70.48068 43.64769, -70.48062 43.6...
# 8   LINESTRING (-70.44005 43.63864, -70.43866 43.6...
# 9   LINESTRING (-70.44745 43.64477, -70.44742 43.6...
# 10  LINESTRING (-70.46067 43.63893, -70.46032 43.6...
# 11  LINESTRING (-70.45897 43.61951, -70.4591 43.61...
# 12  LINESTRING (-70.40418 43.62771, -70.40396 43.6...
# 13  LINESTRING (-70.28932 43.62098, -70.28891 43.6...
# 14  LINESTRING (-70.42964 43.61931, -70.42929 43.6...
# 15  LINESTRING (-70.41519 43.61776, -70.41434 43.6...
# 16  LINESTRING (-70.29637 43.61747, -70.29625 43.6...
# 17  LINESTRING (-70.41563 43.61225, -70.41588 43.6...
# 18  LINESTRING (-70.30472 43.61493, -70.30368 43.6...
# 19  LINESTRING (-70.44312 43.60583, -70.44297 43.6...
# 20  LINESTRING (-70.49662 43.60631, -70.49395 43.6...
# 21  LINESTRING (-70.42531 43.60547, -70.42531 43.6...
# 22  LINESTRING (-70.44755 43.59951, -70.44784 43.5...
# 23  LINESTRING (-70.44482 43.59881, -70.44469 43.5...
# 24  LINESTRING (-70.43669 43.589, -70.43656 43.589...
# 25  LINESTRING (-70.46565 43.58471, -70.46565 43.5...
# 26  LINESTRING (-70.49415 43.59632, -70.49339 43.5...
# 27  LINESTRING (-70.47096 43.59502, -70.47237 43.5...
# 28  LINESTRING (-70.47386 43.5815, -70.4732 43.581...
# 29  LINESTRING (-70.4709 43.58109, -70.47008 43.58...
# 30  LINESTRING (-70.49717 43.58495, -70.49683 43.5...
# 31  LINESTRING (-70.45149 43.57644, -70.4507 43.57...
# 32  LINESTRING (-70.48658 43.57058, -70.48711 43.5...
# 33  LINESTRING (-70.48686 43.5704, -70.48658 43.57...
# 34  LINESTRING (-70.45521 43.56347, -70.45437 43.5...
# 35  LINESTRING (-70.50015 43.62955, -70.4995 43.62...
# 36  LINESTRING (-70.52726 43.6097, -70.52455 43.61...
# 37  LINESTRING (-70.47449 43.56314, -70.47449 43.5...
# 38  LINESTRING (-70.48093 43.64806, -70.48088 43.6...
# 39  LINESTRING (-70.45683 43.55213, -70.45661 43.5...
# 40  LINESTRING (-70.41449 43.61161, -70.41563 43.6...
# 41  LINESTRING (-70.48802 43.5687, -70.48686 43.5704)
# 42  LINESTRING (-70.27312 43.63417, -70.27283 43.6...
# 43  LINESTRING (-70.27835 43.62966, -70.27833 43.6...
# 44  LINESTRING (-70.27838 43.62891, -70.27835 43.6...

# %%
counties['countyWKT'] = counties['countyWKT'].apply(wkt.loads)
counties.drop_duplicates(inplace=True)
counties = gpd.GeoDataFrame(counties, geometry='countyWKT')
counties = counties.simplify(tolerance=0.001)  #simply the county boundary at tolerance of 0.01 degrees for faster mapping
counties.set_crs(epsg=4326, inplace=True, allow_override=True)
# Out:
# 0    POLYGON ((-69.8819 43.63647, -70.13661 43.5334...
# dtype: geometry

# %%
# %%capture
from branca.element import Figure
import math

map = counties.explore(name='Counties',
                       style_kwds=dict(color='Gray',
                                       fill=False,
                                       weight=7))

if 'wb_name' in waterbodies.columns:
    wbcols = ['wb', 'wb_name']
else:
    wbcols = ['wb']

samplept_map.explore(m=map,
                     name=f'<span style="color:DarkOrange;">Samples</span>',
                     color='DarkOrange',
                     style_kwds=dict(style_function=lambda x: {'radius': math.log(float(x['properties']['max'])) * 1.8976 + 3.36937,  # fits to (4 ppt, 6 radius) and (6400 ppt, 20 radius)
                                                               "opacity":1,
                                                               "color":'DimGray'},
                                     fillOpacity=1),
                     marker_kwds=dict(radius=6,
                                      fill=True),
                     marker_type='circle_marker',
                     tooltip=['sp', 'max', 'resultCount'],
                     show=True)

waterbodies.explore(m=map,
                    name='<span style="color:Blue;">Waterbodies</span>',
                    style_kwds=dict(color='Blue',
                                    fill=False,
                                    weight=4),
                    tooltip=wbcols,
                    show=True)

hydrology.explore(m=map,
                  name='<span style="color:Blue;">Upstream Flowlines</span>',
                  color='Blue',
                  style_kwds=dict(weight=1),
                  tooltip=['upstream_flowline', 'us_ftype'],
                  show=False)

c = 0
colors = ['Purple', 'PaleVioletRed', 'Orchid', 'Fuchsia', 'MediumVioletRed', 'HotPink', 'LightPink', 'red', 'lightred', 'pink', 'orange',
          'MidnightBlue', 'MediumBlue', 'SlateBlue', 'MediumSlateBlue', 'DodgerBlue', 'DeepSkyBlue', 'SkyBlue', 'CadetBlue', 'DarkCyan', 'LightSeaGreen',
          'MediumSageGreen', 'lightblue', 'gray', 'blue', 'darkred', 'lightgreen', 'green', 'darkblue', 'darkpurple', 'cadetblue', 'orange', 'lightgray', 'darkgreen']
for industry in list(facilities.industrySubsectorName.unique()):
    facilities[facilities['industrySubsectorName']==industry].explore(m=map,
                                                                      name=f'<span style="color:{colors[c]};">{industry}</span>',
                                                                      color=colors[c],
                                                                      marker_kwds=dict(radius=6,
                                                                                       fill=True),
                                                                      style_kwds=dict(color='black',
                                                                                      fillOpacity=1),
                                                                      marker_type='circle_marker',
                                                                      show=True)
    c += 1

# %% [markdown]
# ## Map

# %%
folium.LayerControl(collapsed=False).add_to(map)
fig = Figure(width='100%', height=700)
fig.add_child(map)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3acfb3ba9aa1e0c070cfba2b4f95b6bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;

# %%
fig.save('SAWGraph_Y3-Kickoff-Demo_TracingUpstream.html')
